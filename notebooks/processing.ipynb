# %%
import sys
import os

# Add the project root directory to sys.path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
# Import the process_data function
from src.data_processing import process_data

from src.data_processing import process_data
import pandas as pd

input_path = '../data/raw/data.csv'
processed = process_data(input_path)

if not isinstance(processed, pd.DataFrame):
    processed = pd.DataFrame(processed)

processed.to_csv('../data/processed/processed_data.csv', index=False)
print('Processed data saved to data/processed/processed_data.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 13
#      10 import pandas as pd
#      12 input_path = '../data/raw/data.csv'
# ---> 13 processed = process_data(input_path)
#      15 if not isinstance(processed, pd.DataFrame):
#      16     processed = pd.DataFrame(processed)
#
# File ~/Documents/10academy/bati-credit-scoring-model/src/data_processing.py:114, in process_data(input_path)
#     112 df = pd.read_csv(input_path)
#     113 pipeline = build_preprocessing_pipeline()
# --> 114 processed = pipeline.fit_transform(df)
#     115 return processed
#
# File ~/.local/share/virtualenvs/bethel-l3XwGefp/lib/python3.10/site-packages/sklearn/base.py:1363, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1356     estimator._validate_params()
#    1358 with config_context(
#    1359     skip_parameter_validation=(
#    1360         prefer_skip_nested_validation or global_skip_validation
#    1361     )
#    1362 ):
# -> 1363     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/share/virtualenvs/bethel-l3XwGefp/lib/python3.10/site-packages/sklearn/pipeline.py:717, in Pipeline.fit_transform(self, X, y, **params)
#     678 """Fit the model and transform with the final estimator.
#     679
#     680 Fit all the transformers one after the other and sequentially transform
#    (...)
#     714     Transformed samples.
#     715 """
#     716 routed_params = self._check_method_params(method="fit_transform", props=params)
# --> 717 Xt = self._fit(X, y, routed_params)
#     719 last_step = self._final_estimator
#     720 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#
# File ~/.local/share/virtualenvs/bethel-l3XwGefp/lib/python3.10/site-packages/sklearn/pipeline.py:587, in Pipeline._fit(self, X, y, routed_params, raw_params)
#     580 # Fit or load from cache the current transformer
#     581 step_params = self._get_metadata_for_step(
#     582     step_idx=step_idx,
#     583     step_params=routed_params[name],
#     584     all_params=raw_params,
#     585 )
# --> 587 X, fitted_transformer = fit_transform_one_cached(
#     588     cloned_transformer,
#     589     X,
#     590     y,
#     591     weight=None,
#     592     message_clsname="Pipeline",
#     593     message=self._log_message(step_idx),
#     594     params=step_params,
#     595 )
#     596 # Replace the transformer of the step with the fitted
#     597 # transformer. This is necessary when loading the transformer
#     598 # from the cache.
#     599 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~/.local/share/virtualenvs/bethel-l3XwGefp/lib/python3.10/site-packages/joblib/memory.py:326, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     325 def __call__(self, *args, **kwargs):
# --> 326     return self.func(*args, **kwargs)
#
# File ~/.local/share/virtualenvs/bethel-l3XwGefp/lib/python3.10/site-packages/sklearn/pipeline.py:1539, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1537 with _print_elapsed_time(message_clsname, message):
#    1538     if hasattr(transformer, "fit_transform"):
# -> 1539         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1540     else:
#    1541         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1542             X, **params.get("transform", {})
#    1543         )
#
# File ~/.local/share/virtualenvs/bethel-l3XwGefp/lib/python3.10/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~/.local/share/virtualenvs/bethel-l3XwGefp/lib/python3.10/site-packages/sklearn/base.py:892, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     877         warnings.warn(
#     878             (
#     879                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)
#     887             UserWarning,
#     888         )
#     890 if y is None:
#     891     # fit method of arity 1 (unsupervised transformation)
# --> 892     return self.fit(X, **fit_params).transform(X)
#     893 else:
#     894     # fit method of arity 2 (supervised transformation)
#     895     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/Documents/10academy/bati-credit-scoring-model/src/data_processing.py:66, in WOEFeatureTransformer.fit(self, X, y)
#      65 def fit(self, X, y=None):
# ---> 66     self.woe = WOE(features=self.categorical_cols)
#      67     self.woe.fit(X, X[self.target_col])
#      68     self.woe_cols = self.woe.features
#
# TypeError: WOE.__init__() got an unexpected keyword argument 'features'
